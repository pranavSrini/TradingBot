# %%
# !pip install pandas numpy statsmodels yfinance matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
# %matplotlib inline

# %%
ticker = 'MSFT'
data = yf.download(ticker, start='2015-01-01', end='2025-08-30')
print(data.iloc[0:3])
print(data.columns)
# Out:
# /var/folders/89/__hq44pj25j7_9nc2vtttg940000gn/T/ipykernel_74241/2082399750.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start='2015-01-01', end='2025-08-30')
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker           MSFT       MSFT       MSFT       MSFT      MSFT
# Date
# 2015-01-02  39.998695  40.563262  39.810509  39.913156  27913900
# 2015-01-05  39.630882  39.973042  39.562448  39.665096  39673900
# 2015-01-06  39.049206  39.990149  38.955111  39.673650  36447900
# MultiIndex([( 'Close', 'MSFT'),
#             (  'High', 'MSFT'),
#             (   'Low', 'MSFT'),
#             (  'Open', 'MSFT'),
#             ('Volume', 'MSFT')],
#            names=['Price', 'Ticker'])

# %%
plt.figure(figsize=(7, 6))
plt.plot(data['Close'], label='Closing Price')
plt.title(f'{ticker} Closing Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
principal = 100000
vol = 50
initial_date = data.index[0]

#set to index of the 'open' price
price_index = 3

initial_price = data.iloc[0,price_index]
print(initial_date)
print(initial_price)
# Out:
# 2015-01-02 00:00:00
# 39.91315626644015
